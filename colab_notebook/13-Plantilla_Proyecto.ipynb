# %% [markdown]
# # Proyecto Final — Diplomado en Analítica de Datos
# ## [ESCRIBE AQUÍ EL TÍTULO DE TU PROYECTO]
# **Autor/a:** [tu nombre]  ·  **Fecha:** [fecha]
#
# > **Instrucciones.** Esta es la *plantilla* del proyecto. Sustituye los bloques marcados con **[TODO]**
# > por tu propio trabajo. El entregable es **este notebook de Colab** con **texto y código** combinados.
# > El proyecto debe **tocar los cuatro módulos** del diplomado. Ejecuta *Runtime → Run all* antes de entregar
# > y asegúrate de que corre **sin errores**.
#
# ### Planteamiento del problema de negocio
# [TODO] Describe en 4–6 líneas: ¿qué problema empresarial/industrial/médico resuelves? ¿por qué importa?
# ¿qué decisión habilitará tu análisis? ¿cuál es la variable objetivo?

# %% [markdown]
# ## 0. Preparación del entorno

# %%
import numpy as np, pandas as pd
import matplotlib.pyplot as plt, seaborn as sns
from scipy import stats
import sqlite3, warnings
warnings.filterwarnings('ignore'); %matplotlib inline
sns.set_theme(style='whitegrid')
print('Entorno listo')

# %% [markdown]
# ## 1. Carga de datos
# [TODO] Carga tu conjunto de datos (CSV, Excel, base de datos...). Si no tienes datos propios, usa un dataset público adecuado a tu problema.

# %%
# [TODO] Sustituye por la carga de tus datos
# df = pd.read_csv('mis_datos.csv')
# df.head()

# %% [markdown]
# ---
# # 🗄️ Módulo 1 — Bases de Datos
# [TODO] Almacena tus datos en una base de datos y recupéralos con **SQL**. Ejecuta al menos una consulta
# de agregación que aporte una primera lectura de negocio. (Comenta cómo se relaciona con NoSQL/Docker si aplica.)

# %%
# [TODO] Ejemplo de estructura — adáptalo a tus datos
# conn = sqlite3.connect('proyecto.db')
# df.to_sql('datos', conn, if_exists='replace', index=False)
# consulta = 'SELECT categoria, COUNT(*) AS n, AVG(objetivo) AS media FROM datos GROUP BY categoria'
# print(pd.read_sql_query(consulta, conn))
# df = pd.read_sql_query('SELECT * FROM datos', conn); conn.close()

# %% [markdown]
# ---
# # 📊 Módulo 2 — Estadística
# [TODO] Análisis exploratorio + estadística descriptiva e inferencial: describe las variables, visualiza
# distribuciones y relaciones, y realiza **al menos un contraste de hipótesis** con su **intervalo de confianza**.

# %%
# [TODO] Estadística descriptiva y visualizaciones
# df.describe()
# sns.histplot(...); plt.show()

# %%
# [TODO] Contraste de hipótesis (t-test / chi-cuadrado / ANOVA...) e intervalo de confianza
# t, p = stats.ttest_ind(grupo_a, grupo_b)
# print('p-valor:', p)

# %% [markdown]
# ---
# # 🧹 Módulo 4 — Preprocesamiento
# [TODO] Prepara los datos para el modelado: valores faltantes, **codificación** de categóricas, **escalado**,
# y si procede **discretización** y **reducción de dimensionalidad (PCA)**. Divide en entrenamiento y prueba.

# %%
# [TODO] Preprocesamiento
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler, OneHotEncoder
# from sklearn.compose import ColumnTransformer
# from sklearn.pipeline import Pipeline
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=42)

# %% [markdown]
# ---
# # 🤖 Módulo 3 — Aprendizaje Automático
# [TODO] Entrena **varios modelos** supervisados (incluye al menos un **ensamble**), realiza **búsqueda de
# hiperparámetros** y **evalúa** con métricas adecuadas (matriz de confusión, ROC-AUC, o R²/MAE si es regresión).
# Interpreta qué variables influyen más.

# %%
# [TODO] Entrenamiento y comparación de modelos
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import GridSearchCV
# ...

# %%
# [TODO] Evaluación del mejor modelo (métricas + gráficas)

# %% [markdown]
# ---
# # 📈 Módulo 4 — Modelado avanzado (opcional pero recomendado)
# [TODO] Añade una extensión: análisis de **series temporales** y/o una **red neuronal** (deep learning) como
# mejora o comparación frente a tu modelo base.

# %%
# [TODO] Serie temporal o red neuronal (MLP / Keras)

# %% [markdown]
# ---
# # ✅ Conclusiones y recomendaciones
# [TODO] Resume:
# 1. Los **hallazgos** principales (¿qué explica tu variable objetivo?).
# 2. El **rendimiento** del modelo final.
# 3. Las **recomendaciones accionables** para la organización.
# 4. **Limitaciones** y próximos pasos.
#
# ### Checklist de entrega
# - [ ] El notebook ejecuta de principio a fin sin errores.
# - [ ] Se usan los **cuatro módulos** (Datos/SQL, Estadística, Preprocesamiento, Modelado).
# - [ ] Cada resultado va acompañado de su **interpretación en texto**.
# - [ ] Hay conclusiones de negocio claras.
